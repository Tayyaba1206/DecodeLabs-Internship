# %%
pip install PyMuPDF

# %%
ipynb_file_path = '/content/Project_1_Rule_Based_AI_Chatbot.ipynb'

try:
    with open(ipynb_file_path, 'r') as f:
        notebook_content = f.read()
    print(notebook_content)
    print(f"\nContent of '{ipynb_file_path}' displayed successfully.")
except FileNotFoundError:
    print(f"Error: The file '{ipynb_file_path}' was not found.")
except Exception as e:
    print(f"An error occurred while reading the notebook file: {e}")
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "b95cd345",
#    "metadata": {},
#    "source": [
#     "# Project 1 - Rule-Based AI Chatbot\n",
#     "\n",
#     "**Goal:** Build a simple rule-based chatbot that responds to predefined user inputs using `if-else` logic in a continuous loop.\n",
#     "\n",
#     "This notebook is designed for Google Colab and follows the project requirements from the training PDF: greetings, exit commands, `if-else` decision-making, and an always-on conversation loop. fileciteturn0file0"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "829e6b39",
#    "metadata": {},
#    "source": [
#     "## Environment Requirements\n",
#     "\n",
#     "- Python 3.x\n",
#     "- Google Colab or Jupyter Notebook\n",
#     "- No external Python packages are required\n",
#     "\n",
#     "The chatbot uses only the Python standard library, so it can run immediately in Colab without installation steps."
#    ]
#   },
#   {
# ...
